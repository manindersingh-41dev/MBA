# %%
print("Hello World")
# Out:
# Hello World

# %%
roll_no = 5
print(roll_no)
# Out:
# 5

# %%
name = "Maninder Singh"
print(name)
# Out:
# Maninder Singh

# %%
_1 = "Maninder"     # allowed Character = alphabets, numeric, underscore

# %%
a = 6

# %%
name
# Out:
# 'Maninder Singh'

# %% [markdown]
# ### Data Types

# %%
type(a)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
num = 5.6

# %%
num
# Out:
# 5.6

# %%
type(num)
# Out:
# float

# %%
valid = True  # True, False

# %%
valid
# Out:
# True

# %%
type(valid)
# Out:
# bool

# %%
var = '50'
var
# Out:
# '50'

# %%
type(var)
# Out:
# str

# %%
var = int(var)

# %%
var
# Out:
# 50

# %%
type(var)
# Out:
# int

# %%
var = float(var)

# %%
var
# Out:
# 50.0

# %%
type(var)
# Out:
# float

# %%
# Case sensitive
name = "Maninder"
Name = "Mansi"

# %%
name
# Out:
# 'Maninder'

# %%
Name
# Out:
# 'Mansi'

# %% [markdown]
# ### Assign multiple values

# %%
a,b,c = 10,20,30

# %%
b
# Out:
# 20

# %%
a
# Out:
# 10

# %%
c
# Out:
# 30

# %%
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %% [markdown]
# # String

# %%
a = "This is 'Python' class"
print(a)
# Out:
# This is 'Python' class

# %%
len(a)
# Out:
# 22

# %%
b = 'This is Python class'
print(b)
# Out:
# This is Python class

# %%
c = "This is 'Python' class"

# %%
print(c)
# Out:
# This is 'Python' class

# %%
d = 'This is "Python" Class'
print(d)
# Out:
# This is "Python" Class

# %%
m_l = '''This
is 
multi-line
string
t
h
i
s

i
s

multi-line
s
t
r
i
n
g
'''

# %%
print(m_l)
# Out:
# This
# is
# multi-line
# string
# t
# h
# i
# s
#
# i
# s
#
# multi-line
# s
# t
# r
# i
# n
# g

# %%
arr = [1,2,3,4]

# %%
print(arr)
# Out:
# [1, 2, 3, 4]

# %%
type(arr)
# Out:
# list

# %%
arr[2]
# Out:
# 3

# %%
arr[0] = 99

# %%
arr
# Out:
# [99, 2, 3, 4]

# %%
a = "Maninder"

# %%
a
# Out:
# 'Maninder'

# %%
a[3]
# Out:
# 'i'

# %%
new_a = a[0:3]+'e'+a[4:]

# %%
new_a
# Out:
# 'Manender'

# %%
a
# Out:
# 'Maninder'

# %%
a[0:3]
# Out:
# 'Man'

# %%
a[4:6]
# Out:
# 'nd'

# %%
a[:3]
# Out:
# 'Man'

# %%
a[4:]
# Out:
# 'nder'

# %%
a = "Maninder"
b = " Singh"

# %%
c = a+b

# %%
print(c)
# Out:
# Maninder Singh

# %%
a = a.replace('i','e')

# %%
print(a)
# Out:
# Manender

# %%
print(c)
# Out:
# Maninder Singh

# %%
d = c.split(" ")

# %%
d
# Out:
# ['Maninder', 'Singh']

# %%
a = "2,3,4,5,6,7"
a_s = a.split(",")

# %%
a_s
# Out:
# ['2', '3', '4', '5', '6', '7']
